# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import re
import nltk
import pandas as pd
# import geopandas as gpd
import urllib.request
from urllib import request
import PyPDF2
# from geotext import GeoText
import seaborn as sns
from collections import Counter
from collections import OrderedDict
import networkx as nx
# from geopy.geocoders import Nominatim
# from geopy.exc import GeocoderTimedOut
sns.set_style('whitegrid')

# %%
plt.rcParams['figure.figsize'] = [16, 9]  # changing parameters for presented plots
font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 18}

plt.rc('font', **font)

# %%
import urllib.request
pdf_path = ""
def download_file(download_url, filename):
    response = urllib.request.urlopen(download_url)    
    file = open(filename + ".pdf", 'wb')
    file.write(response.read().decode('utf-8'))
    file.close()

# %%
url = "https://blogs.ubc.ca/edcp508/files/2016/02/TheLittlePrince.pdf"
def download_file(download_url, filename):
    response = urllib.request.urlopen(download_url)    
    file = open(filename + ".pdf", 'wb')
    file.write(response.read())
    file.close()

# %%
download_file(url, "little_prince")

# %%
file = open("little_prince.pdf", 'rb')
raw = file.read()

# %%
pdfReader = PyPDF2.PdfFileReader(file)
 
# printing number of pages in pdf file
print(pdfReader.numPages)
# Out:
# 64

# %%
pageObj = pdfReader.getPage(5)
 
# extracting text from page
print(pageObj.extractText())
# Out:
# 62  So I lived my life alone, without anyone that I could really talk to, until I had an accident with my plane in the Desert of Sahara, six years ago. Something was broken in my engine. And as I had with me neither a mechanic nor any passengers, I set myself to attempt the difficult repairs all alone. It was a question of life or death for me: I had scarcely enough drinking water to last a week.  The first night, then, I went to sleep on the sand, a thousand miles from any human habitation. I was more isolated than a shipwrecked sailor on a raft in the middle of the ocean. Thus you can imagine my amazement, at sunrise, when I was awakened by an odd little voice. It said:  "If you please--draw me a sheep!"  "What!"  "Draw me a sheep!"  I jumped to my feet, completely thunderstruck. I blinked my eyes hard. I looked carefully all around me. And I saw a most extraordinary small person, who stood there examining me with great seriousness. Here you may see the best portrait that, later, I was able to make of him. But my drawing is certainly very much less charming than its model.   That, however, is not my fault. The grown-ups discouraged me in my painter's career when I was six years old, and I never learned to draw anything, except boas from the outside and boas from the inside.  Now I stared at this sudden apparition with my eyes fairly starting out of my head in astonishment. Remember, I had crashed in the desert a thousand miles from any inhabited region. And yet my little man seemed neither to be straying uncertainly among the sands, nor to be fainting from fatigue or hunger or thirst or fear. Nothing about him gave any suggestion of a child lost in the middle of the desert, a thousand miles from any human habitation. When at last I was able to speak, I said to him:  "But--what are you doing here?"

# %%
text = pdfReader.getPage(5).extractText()
# text.replace("'s ", " is ")
text
# Out:
# '62  So I lived my life alone, without anyone that I could really talk to, until I had an accident with my plane in the Desert of Sahara, six years ago. Something was broken in my engine. And as I had with me neither a mechanic nor any passengers, I set myself to attempt the difficult repairs all alone. It was a question of life or death for me: I had scarcely enough drinking water to last a week.  The first night, then, I went to sleep on the sand, a thousand miles from any human habitation. I was more isolated than a shipwrecked sailor on a raft in the middle of the ocean. Thus you can imagine my amazement, at sunrise, when I was awakened by an odd little voice. It said:  "If you please--draw me a sheep!"  "What!"  "Draw me a sheep!"  I jumped to my feet, completely thunderstruck. I blinked my eyes hard. I looked carefully all around me. And I saw a most extraordinary small person, who stood there examining me with great seriousness. Here you may see the best portrait that, later, I was able to make of him. But my drawing is certainly very much less charming than its model.   That, however, is not my fault. The grown-ups discouraged me in my painter\'s career when I was six years old, and I never learned to draw anything, except boas from the outside and boas from the inside.  Now I stared at this sudden apparition with my eyes fairly starting out of my head in astonishment. Remember, I had crashed in the desert a thousand miles from any inhabited region. And yet my little man seemed neither to be straying uncertainly among the sands, nor to be fainting from fatigue or hunger or thirst or fear. Nothing about him gave any suggestion of a child lost in the middle of the desert, a thousand miles from any human habitation. When at last I was able to speak, I said to him:  "But--what are you doing here?"  '

# %%
numPages = pdfReader.numPages
book = []
for numPage in range(3, 63):
    book.append(pdfReader.getPage(numPage).extractText())

# %%
tempBook = {}
for num, Page in enumerate(book):
    tempBook[num+1] = Page

# %%
book[-1]
# Out:
# '63 This is, to me, the loveliest and saddest landscape in the world. It is the same as that on the preceding page, but I have drawn it again to impress it on your memory. It is here that the little prince appeared on Earth, and disappeared.  Look at it carefully so that you will be sure to recognize it in case you travel some day to the African desert. And, if you should come upon this spot, please do not hurry on. Wait for a time, exactly under the star. Then, if a little man appears who laughs, who has golden hair and who refuses to answer questions, you will know who he is. If this should happen, please comfort me. Send me word that he has come back.           '

# %%
from nltk.tokenize import RegexpTokenizer,word_tokenize,sent_tokenize

# %%
book[43]
# Out:
# '47 "Please--tame me!" he said.  "I want to, very much," the little prince replied. "But I have not much time. I have friends to discover, and a great many things to understand."  "One only understands the things that one tames," said the fox. "Men have no more time to understand anything. They buy things all ready made at the shops. But there is no shop anywhere where one can buy friendship, and so men have no friends any more. If you want a friend, tame me . . ."  "What must I do, to tame you?" asked the little prince.  "You must be very patient," replied the fox. "First you will sit down at a little distance from me--like that--in the grass. I shall look at you out of the corner of my eye, and you will say nothing. Words are the source of misunderstandings. But you will sit a little closer to me, every day . . ."  The next day the little prince came back.  "It would have been better to come back at the same hour," said the fox. "If, for example, you come at four o\'clock in the afternoon, then at three o\'clock I shall begin to be happy. I shall feel happier and happier as the hour advances. At four o\'clock, I shall already be worrying and jumping about. I shall show you how happy I am! But if you come at just any time, I shall never know at what hour my heart is to be ready to greet you . . . One must observe the proper rites . . ."  "What is a rite?" asked the little prince.  "Those also are actions too often neglected," said the fox. "They are what make one day different from other days, one hour from other hours. There is a rite, for example, among my hunters. Every Thursday they dance with the village girls. So Thursday is a wonderful day for me! I can take a walk as far as the vineyards. But if the hunters danced at just any time, every day would be like every other day, and I should never have any vacation at all."   So the little prince tamed the fox. And when the hour of his departure drew near--  "Ah," said the fox, "I shall cry."  '

# %%
for page in book:
    temp = re.findall(r'\d{2,4}\s+\w*\W+',page) 
    if temp:
        print(page[:10])
# Out:
# 41  Once w
# 62  So I l
# 93  It too
# 114  I had
# 135  As ea
# 14 Now the
# 15 Perhaps
# 166  Oh, l
# 177  On th
# 198  I soo
# 229  I bel
# 23 10  He
# 2711  The
# 2912  The
# 3013  The
# 3314  The
# 34"It is n
# 3515  The
# 3816  So t
# 3917  When
# 4218  The
# 43 19  Aft
# 4420  But
# 4521  It w
# 47 "Please
# 4922  "Goo
# 5023  "Goo
# 5124  It w
# 5325  "Men
# 5626  Besi
# 57 I dropp
# 6227  And
# 63 This is

# %%
for page in book:
    temp = re.findall(r'\d{2,4}\s\s\w+',page) #lista
    if temp:
        print(page[:10])
# Out:
# 41  Once w
# 62  So I l
# 93  It too
# 114  I had
# 135  As ea
# 166  Oh, l
# 177  On th
# 198  I soo
# 229  I bel
# 23 10  He
# 2711  The
# 2912  The
# 3013  The
# 3314  The
# 3515  The
# 3816  So t
# 3917  When
# 4218  The
# 43 19  Aft
# 4420  But
# 4521  It w
# 5124  It w
# 5626  Besi
# 6227  And

# %% [markdown]
# ## Deleting stop words. There is need to clean all pages.

# %%
len(book)
# Out:
# 60

# %%
Tokenizer = RegexpTokenizer(r"\w+[A-Za-z0-9-]+")

# %%
newBook = []
for page in book:
#     del(page)
    newPage = Tokenizer.tokenize(page)
#     newBook.append(' '.join(newPage))
    newBook.append(newPage)

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import stopwords
eng_stopwords = stopwords.words("english")

# %%
cleanBook = []
for separatedPage in newBook:
    separated_text_cleaned = [word for word in separatedPage if word.lower() not in eng_stopwords]
    cleanBook.append(separated_text_cleaned)

# %%
from textblob import TextBlob

# %%
plainPages = []
for page in newBook:
    plainPages.append(" ".join(page))

# %%
cleanPages = []
for page in cleanBook:
    cleanPages.append(" ".join(page))

# %%
polarityWithStopWords = {}
subjectivityWithStopWords = {}
for page, text in enumerate(plainPages):
    textBlob = TextBlob(text)
    sentiment = textBlob.sentiment
    polarityWithStopWords[page+1] = sentiment[0]
    subjectivityWithStopWords[page+1] = sentiment[1]
    
polarityWithoutStopWords = {}
subjectivityWithoutStopWords = {}
for page, text in enumerate(cleanPages):
    textBlob = TextBlob(text)
    sentiment = textBlob.sentiment
    polarityWithoutStopWords[page+1] = sentiment[0]
    subjectivityWithoutStopWords[page+1] = sentiment[1]

# %%
pages = list(subjectivityWithStopWords.keys())

polarityWSW = list(polarityWithStopWords.values())
polarityWOSW = list(polarityWithoutStopWords.values())

subjectivityWSW = list(subjectivityWithStopWords.values())
subjectivityWOSW = list(subjectivityWithoutStopWords.values())

# %%
plt.figure(figsize=(16, 9))

plt.title("Polarity of the page with or without $Stop Words$")
plt.plot(pages, polarityWSW, label='WSW')
plt.plot(pages, polarityWOSW, label='W/OSW')
plt.legend(loc=0)

# %%
plt.figure(figsize=(16, 9))

plt.title("Subjectivity of the page with or without $Stop Words$")
plt.plot(pages, subjectivityWSW, label='WSW')
plt.plot(pages, subjectivityWOSW, label='W/OSW')
plt.legend(loc=0)

# %%
textBlob_.sentiment
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-a4a5465076a3> in <module>
# ----> 1 textBlob_.sentiment
#
# NameError: name 'textBlob_' is not defined

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Mateusz\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()
sid.polarity_scores(plainPages[0])
# Out:
# {'neg': 0.051, 'neu': 0.827, 'pos': 0.122, 'compound': 0.9477}

# %%
from collections import OrderedDict

# %%
dictionary = {} # klucze - litery; wartości - ile razy wystapiło na stronie też słownik
for num, Page in enumerate(newBook):
    charactersSequence = "".join(Page).lower()
    characters = {}
    for character in charactersSequence:
#         print(charactersSequence)
        if character not in characters.keys():
            characters[character] = 1
        else:
            characters[character] += 1
    for char in list(characters.keys()):
        if char not in list(dictionary.keys()):
            dictionary[char]={}
            dictionary[char][num+1] = characters[char]
        else:
            dictionary[char][num+1] = characters[char]
temp_dictionary = OrderedDict(sorted(dictionary.items()))

# %%
entireBook = []
# allwords = 0
for Page in newBook:
#     allwords += len(Page)
    entireBook += Page

# %%
words_occur = {}
for word in entireBook:
    temp = word.lower()
    if temp in words_occur.keys():
        words_occur[temp] += 1
    else:
        words_occur[temp] = 1

# %%
sortedWordsOccur = {k: v for k, v in sorted(words_occur.items(), key=lambda item: item[1], reverse=True)}

# %%
list(sortedWordsOccur.items())[:20]
# Out:
# [('the', 971),
#  ('to', 465),
#  ('and', 344),
#  ('of', 334),
#  ('that', 317),
#  ('is', 301),
#  ('he', 296),
#  ('you', 296),
#  ('it', 263),
#  ('little', 258),
#  ('said', 195),
#  ('was', 193),
#  ('prince', 184),
#  ('in', 175),
#  ('my', 162),
#  ('not', 159),
#  ('me', 152),
#  ('but', 146),
#  ('have', 141),
#  ('are', 136)]

# %%
cleanSortWordsOccur = {}
for key in sortedWordsOccur.keys():
    if key not in eng_stopwords:
        cleanSortWordsOccur[key] = sortedWordsOccur[key]

# %%
Words = list(cleanSortWordsOccur.keys())[:30]

# %%
words_per_page = []
for page in newBook:
    Page = []
    for word in Words:
        if word in page:
            Page.append(word)
    words_per_page.append(Page)

# %%
words_per_page
# Out:
# [['said', 'one', 'like', 'time', 'never', 'made', 'see', 'asked', 'could'],
#  ['little', 'one', 'would', 'never', 'stars', 'much', 'man'],
#  ['little', 'said', 'never', 'sheep', 'much', 'man', 'make', 'see', 'could'],
#  ['little', 'said', 'one', 'never', 'sheep', 'made', 'know', 'see'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'like',
#   'time',
#   'sheep',
#   'made',
#   'see',
#   'asked'],
#  ['little',
#   'prince',
#   'planet',
#   'would',
#   'like',
#   'time',
#   'never',
#   'sheep',
#   'made',
#   'come',
#   'shall',
#   'much',
#   'man',
#   'asked',
#   'could'],
#  ['little', 'said', 'prince', 'would', 'good', 'day'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'would',
#   'like',
#   'time',
#   'never',
#   'made',
#   'much',
#   'make'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'would',
#   'like',
#   'good',
#   'time',
#   'never',
#   'sheep',
#   'made',
#   'shall',
#   'much',
#   'know',
#   'make',
#   'see'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'would',
#   'good',
#   'time',
#   'sheep',
#   'made',
#   'come',
#   'make',
#   'day',
#   'asked'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'would',
#   'like',
#   'time',
#   'never',
#   'made',
#   'much',
#   'man',
#   'make',
#   'day',
#   'see',
#   'morning'],
#  ['made'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'like',
#   'time',
#   'made',
#   'much',
#   'day',
#   'see',
#   'morning',
#   'look',
#   'asked',
#   'could'],
#  ['little', 'prince', 'never', 'sheep', 'much', 'know', 'asked'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'like',
#   'flower',
#   'never',
#   'stars',
#   'sheep',
#   'made',
#   'much',
#   'know',
#   'make',
#   'day',
#   'morning',
#   'look',
#   'could'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'would',
#   'like',
#   'flower',
#   'come',
#   'know',
#   'day',
#   'see',
#   'morning',
#   'could',
#   'yes'],
#  ['little',
#   'said',
#   'prince',
#   'planet',
#   'would',
#   'flower',
#   'time',
#   'come',
#   'day',
#   'look',
#   'could'],
#  ['little',
#   'prince',
#   'one',
#   'planet',
#   'good',
#   'never',
#   'made',
#   'come',
#   'much',
#   'know',
#   'day',
#   'look'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'would',
#   'like',
#   'flower',
#   'good',
#   'time',
#   'never',
#   'made',
#   'much',
#   'see',
#   'morning'],
#  ['little',
#   'said',
#   'prince',
#   'planet',
#   'time',
#   'never',
#   'king',
#   'know',
#   'see',
#   'asked',
#   'could'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'would',
#   'good',
#   'stars',
#   'made',
#   'come',
#   'man',
#   'king',
#   'day',
#   'asked',
#   'could'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'would',
#   'like',
#   'flower',
#   'never',
#   'made',
#   'shall',
#   'much',
#   'man',
#   'king',
#   'nothing',
#   'know',
#   'make',
#   'see',
#   'asked'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'like',
#   'good',
#   'time',
#   'made',
#   'king',
#   'make'],
#  ['little', 'said', 'prince', 'one', 'planet', 'man', 'morning'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'never',
#   'come',
#   'much',
#   'man',
#   'king',
#   'make',
#   'asked'],
#  ['little', 'said', 'prince', 'planet'],
#  ['little',
#   'said',
#   'prince',
#   'planet',
#   'time',
#   'never',
#   'made',
#   'much',
#   'man',
#   'make',
#   'morning',
#   'asked'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'like',
#   'good',
#   'time',
#   'stars',
#   'man',
#   'king'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'flower',
#   'never',
#   'stars',
#   'man',
#   'nothing',
#   'know',
#   'day',
#   'could'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'flower',
#   'time',
#   'man',
#   'king',
#   'nothing',
#   'day',
#   'morning',
#   'asked'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'would',
#   'like',
#   'good',
#   'time',
#   'made',
#   'much',
#   'man',
#   'king',
#   'know',
#   'day',
#   'morning',
#   'could'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'come',
#   'much',
#   'man',
#   'look',
#   'asked'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'would',
#   'flower',
#   'good',
#   'never',
#   'come',
#   'shall',
#   'much',
#   'know',
#   'make',
#   'see',
#   'asked'],
#  ['little',
#   'said',
#   'prince',
#   'planet',
#   'would',
#   'flower',
#   'good',
#   'never',
#   'come',
#   'asked'],
#  ['planet', 'would', 'like', 'never', 'come', 'man', 'make'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'time',
#   'come',
#   'much',
#   'know',
#   'make',
#   'see',
#   'could'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'like',
#   'flower',
#   'time',
#   'stars',
#   'made',
#   'come',
#   'king',
#   'day',
#   'asked',
#   'could'],
#  ['said'],
#  ['little', 'said', 'prince', 'one', 'flower', 'never', 'morning', 'asked'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'like',
#   'flower',
#   'shall',
#   'nothing',
#   'see',
#   'morning'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'would',
#   'like',
#   'flower',
#   'time',
#   'come',
#   'much',
#   'make',
#   'see',
#   'morning'],
#  ['little', 'said', 'prince', 'fox', 'nothing', 'morning', 'look', 'asked'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'planet',
#   'like',
#   'flower',
#   'time',
#   'shall',
#   'fox',
#   'nothing',
#   'know',
#   'see',
#   'look'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'would',
#   'like',
#   'time',
#   'never',
#   'made',
#   'come',
#   'shall',
#   'much',
#   'fox',
#   'nothing',
#   'know',
#   'make',
#   'day',
#   'look',
#   'asked'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'would',
#   'like',
#   'good',
#   'time',
#   'never',
#   'made',
#   'come',
#   'much',
#   'fox',
#   'nothing',
#   'make',
#   'see',
#   'look',
#   'could'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'like',
#   'time',
#   'nothing',
#   'know',
#   'morning',
#   'asked'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'would',
#   'like',
#   'time',
#   'made',
#   'morning',
#   'asked'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'flower',
#   'good',
#   'never',
#   'stars',
#   'made',
#   'come',
#   'man',
#   'fox',
#   'nothing',
#   'day',
#   'look',
#   'could'],
#  ['little', 'said', 'prince', 'one', 'like', 'stars', 'fox', 'nothing', 'see'],
#  ['little', 'said', 'prince', 'one', 'like', 'come', 'know'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'like',
#   'flower',
#   'good',
#   'stars',
#   'sheep',
#   'know',
#   'make',
#   'see',
#   'look',
#   'could'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'like',
#   'never',
#   'made',
#   'fox',
#   'know',
#   'morning'],
#  ['little',
#   'said',
#   'prince',
#   'good',
#   'time',
#   'shall',
#   'nothing',
#   'make',
#   'day',
#   'see',
#   'yes'],
#  ['little', 'said', 'prince', 'one', 'like', 'time', 'made', 'man', 'know'],
#  ['little',
#   'said',
#   'one',
#   'like',
#   'flower',
#   'good',
#   'time',
#   'never',
#   'stars',
#   'sheep',
#   'shall',
#   'much',
#   'man',
#   'nothing',
#   'know',
#   'see',
#   'look',
#   'could'],
#  ['little',
#   'said',
#   'prince',
#   'one',
#   'like',
#   'time',
#   'stars',
#   'come',
#   'shall',
#   'know',
#   'make',
#   'see',
#   'look'],
#  ['little',
#   'said',
#   'one',
#   'like',
#   'flower',
#   'stars',
#   'made',
#   'come',
#   'shall',
#   'nothing',
#   'know',
#   'see',
#   'look',
#   'could'],
#  ['nothing'],
#  ['little',
#   'prince',
#   'one',
#   'planet',
#   'like',
#   'flower',
#   'time',
#   'never',
#   'stars',
#   'sheep',
#   'much',
#   'nothing',
#   'know',
#   'see',
#   'yes'],
#  ['little', 'prince', 'time', 'come', 'man', 'know', 'day']]

# %%
coocur=[]
for page in list(words_per_page):
    if len(page)>1:
        for j in range(len(page)):
            for k in range(j+1,len(page)):
                coocur.append((page[j],page[k]))

# %%
weight = list(np.array(list(Counter(coocur).values()))/10)  
edges= list(Counter(coocur))

# %%
G=nx.Graph()
for e in range(len(edges)):
    G.add_edge(edges[e][0], edges[e][1], weight=weight[e])

# %%
node_size = []
count = 0
for word in list(G.nodes):
    for page in words_per_page:
        if word in page:
            count += 1
    node_size.append(count * 30)
    count = 0

# %%
fig= plt.figure(figsize=(20,20))
nx.draw(G, pos = nx.shell_layout(G),  width=weight , node_size=node_size, edge_color='green')
nx.draw_networkx_labels(G, pos = nx.shell_layout(G), font_color = 'black', font_size=25)
plt.savefig('graph.png')
plt.show()
# Out:
# MatplotlibDeprecationWarning: isinstance(..., numbers.Number) [nx_pylab.py:611]
